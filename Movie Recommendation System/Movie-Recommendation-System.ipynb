# %%
import numpy as np
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Getting data set

# %%
columns_names = ['user_id', 'item_id', 'rating', 'timestamp']

df = pd.read_csv('ml-100k/u.data', sep='\t', names = columns_names ) #u.data is not a csv file instead it is a tab seperated value file so we need to give sep='\t'

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
 df.shape
# Out:
# (100000, 4)

# %%
# to check how many different users are there

df['user_id'].nunique()
# Out:
# 943

# %%
df['item_id'].nunique()
# Out:
# 1682

# %%
# now we dont know which id corrsp to which movie so for that they have given u.item file

# %%
# reading u.item file

# pd.read_csv('ml-100k/u.item', sep='\|', header = None) but we are interessted in only first two columns

# %%
movies_title = pd.read_csv('ml-100k/u.item', sep='\|', header = None)

# %%
movies_title.shape
# Out:
# (1682, 24)

# %%
movies_title = movies_title[[0,1]]

# %%
movies_title.columns = ['item_id', 'title']

movies_title.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
# merging two data frames

new_df = pd.merge(df, movies_title, on='item_id')

# %%
new_df
# Out:
#        user_id  item_id  rating  timestamp  \
# 0          196      242       3  881250949
# 1           63      242       3  875747190
# 2          226      242       5  883888671
# 3          154      242       3  879138235
# 4          306      242       5  876503793
# ...        ...      ...     ...        ...
# 99995      840     1674       4  891211682
# 99996      655     1640       3  888474646
# 99997      655     1637       3  888984255
# 99998      655     1630       3  887428735
# 99999      655     1641       3  887427810
#
#                                                    title
# 0                                           Kolya (1996)
# 1                                           Kolya (1996)
# 2                                           Kolya (1996)
# 3                                           Kolya (1996)
# 4                                           Kolya (1996)
# ...                                                  ...
# ...

# %%
new_df.tail()
# Out:
#        user_id  item_id  rating  timestamp  \
# 99995      840     1674       4  891211682
# 99996      655     1640       3  888474646
# 99997      655     1637       3  888984255
# 99998      655     1630       3  887428735
# 99999      655     1641       3  887427810
#
#                                                    title
# 99995                                  Mamma Roma (1962)
# 99996                             Eighth Day, The (1996)
# 99997                                  Girls Town (1996)
# 99998  Silence of the Palace, The (Saimt el Qusur) (1...
# 99999                                    Dadetown (1995)

# %% [markdown]
# # Exploratory data analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# %%
new_df
# Out:
#        user_id  item_id  rating  timestamp  \
# 0          196      242       3  881250949
# 1           63      242       3  875747190
# 2          226      242       5  883888671
# 3          154      242       3  879138235
# 4          306      242       5  876503793
# ...        ...      ...     ...        ...
# 99995      840     1674       4  891211682
# 99996      655     1640       3  888474646
# 99997      655     1637       3  888984255
# 99998      655     1630       3  887428735
# 99999      655     1641       3  887427810
#
#                                                    title
# 0                                           Kolya (1996)
# 1                                           Kolya (1996)
# 2                                           Kolya (1996)
# 3                                           Kolya (1996)
# 4                                           Kolya (1996)
# ...                                                  ...
# ...

# %%
new_df.groupby('title').mean()
# Out:
#                                           user_id  item_id    rating  \
# title
# 'Til There Was You (1997)              383.777778   1300.0  2.333333
# 1-900 (1994)                           477.000000   1353.0  2.600000
# 101 Dalmatians (1996)                  450.330275    225.0  2.908257
# 12 Angry Men (1957)                    453.552000    178.0  4.344000
# 187 (1997)                             517.097561    330.0  3.024390
# ...                                           ...      ...       ...
# Young Guns II (1990)                   504.068182   1188.0  2.772727
# Young Poisoner's Handbook, The (1995)  452.487805    547.0  3.341463
# Zeus and Roxanne (1997)                532.833333   1164.0  2.166667
# unknown                                311.888889    267.0  3.444444
# Á köldum klaka (Cold Fever) (1994)     655.000000   1633.0  3.000000
#
#                                           timestamp
# title
# 'Til There Was You (1997)              8.861152e+08
# ...

# %%
# we are intrested in mean rating

new_df.groupby('title').mean()['rating']
# Out:
# title
# 'Til There Was You (1997)                2.333333
# 1-900 (1994)                             2.600000
# 101 Dalmatians (1996)                    2.908257
# 12 Angry Men (1957)                      4.344000
# 187 (1997)                               3.024390
#                                            ...
# Young Guns II (1990)                     2.772727
# Young Poisoner's Handbook, The (1995)    3.341463
# Zeus and Roxanne (1997)                  2.166667
# unknown                                  3.444444
# Á köldum klaka (Cold Fever) (1994)       3.000000
# Name: rating, Length: 1664, dtype: float64

# %%
# which movie has heighes avg rating --> use sort_values()

new_df.groupby('title').mean()['rating'].sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
new_df.groupby('title').count()['rating'].sort_values(ascending=False) # rating column will tell how many times this movie has got rating
# Out:
# title
# Star Wars (1977)                              583
# Contact (1997)                                509
# Fargo (1996)                                  508
# Return of the Jedi (1983)                     507
# Liar Liar (1997)                              485
#                                              ...
# Man from Down Under, The (1943)                 1
# Marlene Dietrich: Shadow and Light (1996)       1
# Mat' i syn (1997)                               1
# Mille bolle blu (1993)                          1
# Á köldum klaka (Cold Fever) (1994)              1
# Name: rating, Length: 1664, dtype: int64

# %%
ratings_df = pd.DataFrame(new_df.groupby('title').mean()['rating']) #dataframe of avg ratings of all movies

# %%
ratings_df.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings_df['number of ratings']  = pd.DataFrame(new_df.groupby('title').count()['rating'])

# %%
ratings_df
# Out:
#                                          rating  number of ratings
# title
# 'Til There Was You (1997)              2.333333                  9
# 1-900 (1994)                           2.600000                  5
# 101 Dalmatians (1996)                  2.908257                109
# 12 Angry Men (1957)                    4.344000                125
# 187 (1997)                             3.024390                 41
# ...                                         ...                ...
# Young Guns II (1990)                   2.772727                 44
# Young Poisoner's Handbook, The (1995)  3.341463                 41
# Zeus and Roxanne (1997)                2.166667                  6
# unknown                                3.444444                  9
# Á köldum klaka (Cold Fever) (1994)     3.000000                  1
#
# [1664 rows x 2 columns]

# %%
ratings_df.sort_values(by='rating',ascending=False)
# Out:
#                                               rating  number of ratings
# title
# They Made Me a Criminal (1939)                   5.0                  1
# Marlene Dietrich: Shadow and Light (1996)        5.0                  1
# Saint of Fort Washington, The (1993)             5.0                  2
# Someone Else's America (1995)                    5.0                  1
# Star Kid (1997)                                  5.0                  3
# ...                                              ...                ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)     1.0                  1
# King of New York (1990)                          1.0                  1
# Touki Bouki (Journey of the Hyena) (1973)        1.0                  1
# Bloody Child, The (1996)                         1.0                  1
# Crude Oasis, The (1995)                          1.0                  1
#
# [1664 rows x 2 columns]

# %%
# we have to discard all the movies which have 1 or 2 no of ratings bcoz they do not provide us accurate data

# %%
# so we can plot histogram of no of ratings

# %%
plt.figure(figsize=(10,6))
plt.hist(ratings_df['number of ratings'], bins=70)
plt.show()

# %%
# so approximately 0-30 on x axis is not relevant

# %%
plt.hist(ratings_df['rating'], bins = 70)
plt.show()

# %%
sns.jointplot(x='rating', y='number of ratings', data = ratings_df, alpha = 0.5)

# %%
# this graph concludes that as the rating increases the number of ratings also increases

# %% [markdown]
# # Creating Movie Recommendation

# %%
new_df.head()
# Out:
#    user_id  item_id  rating  timestamp         title
# 0      196      242       3  881250949  Kolya (1996)
# 1       63      242       3  875747190  Kolya (1996)
# 2      226      242       5  883888671  Kolya (1996)
# 3      154      242       3  879138235  Kolya (1996)
# 4      306      242       5  876503793  Kolya (1996)

# %%
# creating a pivot table

moviemat = new_df.pivot_table(index= "user_id", columns= "title", values= "rating")

# %%
moviemat
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
# movie that has heighest rating 

starwar_user_ratings = moviemat['Star Wars (1977)']
starwar_user_ratings.head()
# Out:
# user_id
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    4.0
# Name: Star Wars (1977), dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwar_user_ratings)

similar_to_starwars
# Out:
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# Young Guns II (1990)                     0.228615
# Young Poisoner's Handbook, The (1995)   -0.007374
# Zeus and Roxanne (1997)                  0.818182
# unknown                                  0.723123
# Á köldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
corr_starwars = pd.DataFrame(similar_to_starwars, columns=['correlation'])

# %%
corr_starwars.dropna(inplace = True)

# %%
corr_starwars
# Out:
#                                        correlation
# title
# 'Til There Was You (1997)                 0.872872
# 1-900 (1994)                             -0.645497
# 101 Dalmatians (1996)                     0.211132
# 12 Angry Men (1957)                       0.184289
# 187 (1997)                                0.027398
# ...                                            ...
# Young Guns (1988)                         0.186377
# Young Guns II (1990)                      0.228615
# Young Poisoner's Handbook, The (1995)    -0.007374
# Zeus and Roxanne (1997)                   0.818182
# unknown                                   0.723123
#
# [1410 rows x 1 columns]

# %%
corr_starwars.head()
# Out:
#                            correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
# corr_starwars = corr_starwars.sort_values('correlation',ascending=False)

# %%
# perfect correlation may occur due to less number of user rated same movies
# to over come this we have to do some filteration --> we are putting a thresh hold that if movie is rated by 100 users  then only consider suggestion that movie

# %%
ratings_df
# Out:
#                                          rating  number of ratings
# title
# 'Til There Was You (1997)              2.333333                  9
# 1-900 (1994)                           2.600000                  5
# 101 Dalmatians (1996)                  2.908257                109
# 12 Angry Men (1957)                    4.344000                125
# 187 (1997)                             3.024390                 41
# ...                                         ...                ...
# Young Guns II (1990)                   2.772727                 44
# Young Poisoner's Handbook, The (1995)  3.341463                 41
# Zeus and Roxanne (1997)                2.166667                  6
# unknown                                3.444444                  9
# Á köldum klaka (Cold Fever) (1994)     3.000000                  1
#
# [1664 rows x 2 columns]

# %%
corr_starwars = corr_starwars.join(ratings_df['number of ratings'])

# %%
corr_starwars
# Out:
#                                        correlation  number of ratings
# title
# 'Til There Was You (1997)                 0.872872                  9
# 1-900 (1994)                             -0.645497                  5
# 101 Dalmatians (1996)                     0.211132                109
# 12 Angry Men (1957)                       0.184289                125
# 187 (1997)                                0.027398                 41
# ...                                            ...                ...
# Young Guns (1988)                         0.186377                101
# Young Guns II (1990)                      0.228615                 44
# Young Poisoner's Handbook, The (1995)    -0.007374                 41
# Zeus and Roxanne (1997)                   0.818182                  6
# unknown                                   0.723123                  9
#
# [1410 rows x 2 columns]

# %%
corr_starwars[corr_starwars['number of ratings']>100].sort_values('correlation', ascending = False)
# Out:
#                                                     correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.747981
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
# ...                                                         ...
# Edge, The (1997)                                      -0.127167
# As Good As It Gets (1997)                             -0.130466
# Crash (1996)                                          -0.148507
# G.I. Jane (1997)                                      -0.176734
# First Wives Club, The (1996)                          -0.194496
#
#                                                     number of ratings
# title
# Star Wars (1977)                                                  583
# ...

# %% [markdown]
# # Predict function

# %%
def predict_movies(movie_name):
    movie_user_ratings = moviemat[movie_name]
    similar_to_movie = moviemat.corrwith(movie_user_ratings)
    corr_movie = pd.DataFrame(similar_to_movie, columns=['correlation'])
    corr_movie.dropna(inplace = True)
    corr_movie = corr_movie.join(ratings_df['number of ratings'])
    predictions = corr_movie[corr_movie['number of ratings']>100].sort_values('correlation', ascending = False)
    
    return predictions

# %%
predictions = predict_movies("Titanic (1997)")

# %%
predictions
# Out:
#                                   correlation  number of ratings
# title
# Titanic (1997)                       1.000000                350
# River Wild, The (1994)               0.497600                146
# Abyss, The (1989)                    0.472103                151
# Bram Stoker's Dracula (1992)         0.443560                120
# True Lies (1994)                     0.435104                208
# ...                                       ...                ...
# Raging Bull (1980)                  -0.223660                116
# Jackie Brown (1997)                 -0.236841                126
# Brazil (1985)                       -0.243532                208
# Cold Comfort Farm (1995)            -0.307150                125
# James and the Giant Peach (1996)    -0.370248                126
#
# [334 rows x 2 columns]
