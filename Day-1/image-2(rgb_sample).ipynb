# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("RGB.jfif")
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=301x167 at 0x233E0994E88>

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (167, 301, 3)

# %%
red = arr[100:200 ,:, 2]

# %%
plt.imshow(red)
